# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib import rcParams
import seaborn as sns

r = input('2017~2019: ')

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

bb = 0
cc = 0
dd = 0
rr = 0
for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bb = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사고건수 %d"%(rr,bb))
        
    elif r == i[0] and '부상자수' in i[1]:
        cc = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 부상자수 %d"%(rr,cc))
        
    elif r == i[0] and '사망건수' in i[1]:
        dd = int(i[2].replace(',',''))
        rr = int(i[0])
        print("%d년도 사망건수 %d"%(rr,dd))


f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)
header = next(data)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ds = int(i[4].replace(',',''))
        print('동구 사고건수 :',ds)     
    elif r == i[0] and '사망건수' in i[1]:
        dss1 = int(i[4].replace(',',''))
        print('동구 사망건수 :',dss1)
    elif r == i[0] and '부상자수' in i[1]:
        db = int(i[4].replace(',',''))
        print('동구 부상자수 :',db) 
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        js = int(i[3].replace(',',''))
        print('중구 사고건수 :',js)     
    elif r == i[0] and '사망건수' in i[1]:
        jss = int(i[3].replace(',',''))
        print('중구 사망건수 :',jss)
    elif r == i[0] and '부상자수' in i[1]:
        jb = int(i[3].replace(',',''))
        print('중구 부상자수 :',jb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ss = int(i[5].replace(',',''))
        print('서구 사고건수 :',ss)     
    elif r == i[0] and '사망건수' in i[1]:
        sss1 = int(i[5].replace(',',''))
        print('서구 사망건수 :',sss1)
    elif r == i[0] and '부상자수' in i[1]:
        sb = int(i[5].replace(',',''))
        print('서구 부상자수 :',sb)

f.close()



f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        ns = int(i[6].replace(',',''))
        print('남구 사고건수 :',ns)     
    elif r == i[0] and '사망건수' in i[1]:
        nss = int(i[6].replace(',',''))
        print('남구 사망건수 :',nss)
    elif r == i[0] and '부상자수' in i[1]:
        nb = int(i[6].replace(',',''))
        print('남구 부상자수 :',nb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sus = int(i[8].replace(',',''))
        print('수성구 사고건수 :',sus)     
    elif r == i[0] and '사망건수' in i[1]:
        suss = int(i[8].replace(',',''))
        print('수성구 사망건수 :',suss)
    elif r == i[0] and '부상자수' in i[1]:
        sub = int(i[8].replace(',',''))
        print('수성구 부상자수 :',sub)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bs = int(i[7].replace(',',''))
    #    print('북부 사고건수 :',bs)     
    elif r == i[0] and '사망건수' in i[1]:
        bss = int(i[7].replace(',',''))
    #    print('북부 사망건수 :',bss)
    elif r == i[0] and '부상자수' in i[1]:
        b3 = int(i[7].replace(',',''))
   #     print('북부 부상자수 :',bb)

f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)


for i in data:
    if r == i[0] and '사고건수' in i[1]:
        bbs = int(i[12].replace(',',''))
     #   print('강북 사고건수 :',bbs)     
    elif r == i[0] and '사망건수' in i[1]:
        bbss = int(i[12].replace(',',''))
      #  print('강북 사망건수 :',bbss)
    elif r == i[0] and '부상자수' in i[1]:
        bbb = int(i[12].replace(',',''))
     #   print('강북 부상자수 :',bbb)

f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        dss = int(i[9].replace(',',''))
    #    print('달서 사고건수 :',dss)     
    elif r == i[0] and '사망건수' in i[1]:
        ddss = int(i[9].replace(',',''))
     #   print('달서 사망건수 :',ddss)
    elif r == i[0] and '부상자수' in i[1]:
        dsb = int(i[9].replace(',',''))
      #  print('달서 부상자수 :',dsb)
        
f.close()

f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        sss = int(i[10].replace(',',''))
   #     print('성서 사고건수 :',sss)     
    elif r == i[0] and '사망건수' in i[1]:
        ssss = int(i[10].replace(',',''))
     #   print('성서 사망건수 :',ssss)
    elif r == i[0] and '부상자수' in i[1]:
        ssb = int(i[10].replace(',',''))
    #    print('성서 부상자수 :',ssb)
        
f.close()


f = open('Daegu.csv',encoding = 'cp949')
data = csv.reader(f)

for i in data:
    if r == i[0] and '사고건수' in i[1]:
        d1s = int(i[11].replace(',',''))
        print('달성 사고건수 :',d1s)     
    elif r == i[0] and '사망건수' in i[1]:
        d2s = int(i[11].replace(',',''))
        print('달성 사망건수 :',d2s)
    elif r == i[0] and '부상자수' in i[1]:
        d3s = int(i[11].replace(',',''))
        print('달성 부상자수 :',d3s)
        
f.close()




hhh5 = bs + bbs
hhh6 = bss + bbss
hhh7 = b3 + bbb

print('북구 사고 건수 : ',hhh5)
print('북구 사망 건수 : ',hhh6)
print('북구 부상 자수 : ',hhh7)




pp = dss + sss
pp2 = ddss + ssss
pp3 = dsb + ssb

print('달서구 사고 건수 : ',pp)
print('달서구 사망 건수 : ',pp2)
print('달서구 부상 건수 : ',pp3)

f = open('drunk.csv',encoding = 'cp949')
data1 = csv.reader(f)

tt = 0

for m in data1 :
    if m[0] == '대구광역시'  and r == '2017':
        tt = int(m[8].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2018':
        tt = int(m[11].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))
    elif m[0] == '대구광역시'  and r == '2019':
        tt = int(m[14].replace(',',''))
        rr = int(r)
        print("%d년도 음주운전건수 %d"%(rr,tt))



f.close()



plt.rc('font',family = 'Gulim')
plt.rc('legend',fontsize = 12,loc='best')

title_font = {
    'fontsize' : 25,
    'fontweight' : 'bold'}

plt.figure(figsize = (10,10))
label = ['사망자수','부상자수','사고건수','음주운전건수']
index =np.arange(len(label))
traffic_accident = [dd,cc,bb,rr]
plt.xticks(index,label,fontsize = 20)
plt.title('%d년도 대구교통사고 통계'%rr,fontdict=title_font)
plt.bar(range(len(traffic_accident)),traffic_accident,color = ['yellowgreen'])





plt.figure(figsize = (10,10))
size = [ds,js,ss,ns,sus,hhh5,pp,d1s]
label = ['동구','중구','서구','남구','수성구','북구','달서구','달성군']
plt.pie(size, labels = label, autopct = '%.1f%%',textprops={'fontsize':20}, colors = ['peachpuff','pink','lightcoral','palevioletred','orchid','mediumorchid','m','darkorchid'], wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth':7})
plt.title('%d년도 사고건수'%rr,fontdict=title_font)
plt.legend()



plt.figure(figsize = (10,10))
size = [dss1,jss,sss1,nss,suss,hhh6,pp2,d2s]
label = ['동구','중구','서구','남구','수성구','북구','달서구','달성군']
plt.pie(size, labels = label, autopct = '%.1f%%',textprops={'fontsize':20}, colors = ['khaki','palegoldenrod','greenyellow','lightgreen','mediumseagreen','mediumaquamarine','lightseagreen','cadetblue'], wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth':7})
plt.title('%d년도 사고건수'%rr,fontdict=title_font)
plt.title('%d년도 사망자수'%rr,fontdict=title_font)
plt.legend()


plt.figure(figsize = (10,10))
size = [db,jb,sb,nb,sub,hhh7,pp3,d3s]
label = ['동구','중구','서구','남구','수성구','북구','달서구','달성군']
plt.pie(size, labels = label, autopct = '%.1f%%',textprops={'fontsize':20},colors = ['orangered','orange','yellowgreen','mediumaquamarine','cornflowerblue','mediumpurple','violet','lightgrey'], wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth':7})
plt.title('%d년도 부상자수'%rr,fontdict=title_font)
plt.legend()
plt.show()
# Out:
# 2017~2019: 2017
# 2017년도 사고건수 12870
# 2017년도 사망건수 136
# 2017년도 부상자수 18336
# 동구 사고건수 : 1575
# 동구 사망건수 : 19
# 동구 부상자수 : 2281
# 중구 사고건수 : 994
# 중구 사망건수 : 6
# 중구 부상자수 : 1421
# 서구 사고건수 : 1294
# 서구 사망건수 : 15
# 서구 부상자수 : 1853
# 남구 사고건수 : 813
# 남구 사망건수 : 9
# 남구 부상자수 : 1171
# 수성구 사고건수 : 2012
# 수성구 사망건수 : 20
# 수성구 부상자수 : 2894
# 달성 사고건수 : 855
# 달성 사망건수 : 26
# 달성 부상자수 : 1174
# 북구 사고 건수 :  2189
# 북구 사망 건수 :  22
# 북구 부상 자수 :  3035
# 달서구 사고 건수 :  3138
# 달서구 사망 건수 :  19
# 달서구 부상 건수 :  4507
# 2017년도 음주운전건수 890
